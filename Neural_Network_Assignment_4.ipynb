# %%
# !pip install mnist
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mnist in /usr/local/lib/python3.7/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mnist) (1.21.6)

# %%
import mnist
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import itertools

# %%
class Conv3x3:
  def __init__(self, num_filters):
    self.num_filters = num_filters
    self.filters = np.random.randn(num_filters, 3, 3) / 9

  def iterate_regions(self, image):
    h, w = image.shape

    for i in range(h - 2):
      for j in range(w - 2):
        im_region = image[i:(i + 3), j:(j + 3)]
        yield im_region, i, j

  def forward(self, input):
    self.last_input = input

    h, w = input.shape
    output = np.zeros((h - 2, w - 2, self.num_filters))

    for im_region, i, j in self.iterate_regions(input):
      output[i, j] = np.sum(im_region * self.filters, axis=(1, 2))

    return output

  def backprop(self, d_L_d_out, learn_rate):
    d_L_d_filters = np.zeros(self.filters.shape)

    for im_region, i, j in self.iterate_regions(self.last_input):
      for f in range(self.num_filters):
        d_L_d_filters[f] += d_L_d_out[i, j, f] * im_region
    self.filters -= learn_rate * d_L_d_filters
    return None

# %%
class MaxPool2:
  def iterate_regions(self, image):
    h, w, _ = image.shape
    new_h = h // 2
    new_w = w // 2

    for i in range(new_h):
      for j in range(new_w):
        im_region = image[(i * 2):(i * 2 + 2), (j * 2):(j * 2 + 2)]
        yield im_region, i, j

  def forward(self, input):
    self.last_input = input

    h, w, num_filters = input.shape
    output = np.zeros((h // 2, w // 2, num_filters))

    for im_region, i, j in self.iterate_regions(input):
      output[i, j] = np.amax(im_region, axis=(0, 1))

    return output

  def backprop(self, d_L_d_out):
    d_L_d_input = np.zeros(self.last_input.shape)

    for im_region, i, j in self.iterate_regions(self.last_input):
      h, w, f = im_region.shape
      amax = np.amax(im_region, axis=(0, 1))

      for i2 in range(h):
        for j2 in range(w):
          for f2 in range(f):
            # If this pixel was the max value, copy the gradient to it.
            if im_region[i2, j2, f2] == amax[f2]:
              d_L_d_input[i * 2 + i2, j * 2 + j2, f2] = d_L_d_out[i, j, f2]

    return d_L_d_input

# %%
class Softmax:
  def __init__(self, input_len, nodes):
    self.weights = np.random.randn(input_len, nodes) / input_len
    self.biases = np.zeros(nodes)

  def forward(self, input):
    self.last_input_shape = input.shape

    input = input.flatten()
    self.last_input = input

    input_len, nodes = self.weights.shape

    totals = np.dot(input, self.weights) + self.biases
    self.last_totals = totals

    exp = np.exp(totals)
    return exp / np.sum(exp, axis=0)

  def backprop(self, d_L_d_out, learn_rate):
    for i, gradient in enumerate(d_L_d_out):
      if gradient == 0:
        continue
      t_exp = np.exp(self.last_totals)
      S = np.sum(t_exp)

      d_out_d_t = -t_exp[i] * t_exp / (S ** 2)
      d_out_d_t[i] = t_exp[i] * (S - t_exp[i]) / (S ** 2)

      d_t_d_w = self.last_input
      d_t_d_b = 1
      d_t_d_inputs = self.weights

      d_L_d_t = gradient * d_out_d_t

      d_L_d_w = d_t_d_w[np.newaxis].T @ d_L_d_t[np.newaxis]
      d_L_d_b = d_L_d_t * d_t_d_b
      d_L_d_inputs = d_t_d_inputs @ d_L_d_t

      # Update weights / biases
      self.weights -= learn_rate * d_L_d_w
      self.biases -= learn_rate * d_L_d_b

      return d_L_d_inputs.reshape(self.last_input_shape)

# %%
n = 10000
train_images = mnist.train_images()[:n]
train_labels = mnist.train_labels()[:n]
test_images = mnist.test_images()[:n]
test_labels = mnist.test_labels()[:n]
train_images[0].shape
# Out:
# (28, 28)

# %%
# run
conv = Conv3x3(8)                  # 28x28x1 -> 26x26x8
pool = MaxPool2()                  # 26x26x8 -> 13x13x8
softmax = Softmax(13 * 13 * 8, 10) # 13x13x8 -> 10

def forward(image, label):
  out = conv.forward((image / 255) - 0.5)
  out = pool.forward(out)
  out = softmax.forward(out)

  loss = -np.log(out[label])
  acc = 1 if np.argmax(out) == label else 0

  return out, loss, acc

def train(im, label, lr=.005):
  out, loss, acc = forward(im, label)

  gradient = np.zeros(10)
  gradient[label] = -1 / out[label]

  gradient = softmax.backprop(gradient, lr)
  gradient = pool.backprop(gradient)
  gradient = conv.backprop(gradient, lr)

  return loss, acc


# Train the CNN for k epochs

acc_g = []
for epoch in range(4):
  print('--- Epoch %d ---' % (epoch + 1))

  permutation = np.random.permutation(len(train_images))
  train_images = train_images[permutation]
  train_labels = train_labels[permutation]

  loss = 0
  num_correct = 0

  corr_pred = 0
  

  for i, (im, label) in enumerate(zip(train_images, train_labels)):
    if i % 100 == 99:
      print(
        '[Step %d] Past 100 steps: Average Loss %.3f | Accuracy: %d%%' %
        (i + 1, loss / 100, num_correct)
      )
      loss = 0
      num_correct = 0

    l, acc = train(im, label)
    loss += l
    num_correct += acc
    corr_pred += acc
  acc_g.append(corr_pred/n)
  corr_pred = 0

print ('Accuracy over epochs: ', acc_g)
plt.plot(acc_g)

# Test the CNN
print('\n--- Testing the CNN ---')
loss = 0
num_correct = 0
pred = []
for im, label in zip(test_images, test_labels):
  p , l, acc = forward(im, label)
  loss += l
  num_correct += acc
  pred.append(np.argmax(np.round(p)))
pred = np.array(pred)

num_tests = len(test_images)
print('Test Loss:', loss / num_tests)
print('Test Accuracy:', num_correct / num_tests)
# Out:
# --- Epoch 1 ---
# [Step 100] Past 100 steps: Average Loss 2.206 | Accuracy: 26%
# [Step 200] Past 100 steps: Average Loss 1.904 | Accuracy: 49%
# [Step 300] Past 100 steps: Average Loss 1.468 | Accuracy: 54%
# [Step 400] Past 100 steps: Average Loss 1.137 | Accuracy: 60%
# [Step 500] Past 100 steps: Average Loss 1.007 | Accuracy: 68%
# [Step 600] Past 100 steps: Average Loss 0.905 | Accuracy: 72%
# [Step 700] Past 100 steps: Average Loss 0.610 | Accuracy: 77%
# [Step 800] Past 100 steps: Average Loss 0.698 | Accuracy: 77%
# [Step 900] Past 100 steps: Average Loss 0.797 | Accuracy: 72%
# [Step 1000] Past 100 steps: Average Loss 0.652 | Accuracy: 78%
# [Step 1100] Past 100 steps: Average Loss 0.598 | Accuracy: 81%
# [Step 1200] Past 100 steps: Average Loss 0.589 | Accuracy: 83%
# [Step 1300] Past 100 steps: Average Loss 0.513 | Accuracy: 85%
# [Step 1400] Past 100 steps: Average Loss 0.521 | Accuracy: 86%
# [Step 1500] Past 100 steps: Average Loss 0.545 | Accuracy: 81%
# [Step 1600] Past 100 steps: Average Loss 0.534 | Accuracy: 84%
# [Step 1700] Past 100 steps: Average Loss 0.542 | Accuracy: 82%
# [Step 1800] Past 100 steps: Average Loss 0.755 | Accuracy: 76%
# [Step 1900] Past 100 steps: Average Loss 0.411 | Accuracy: 88%
# [Step 2000] Past 100 steps: Average Loss 0.472 | Accuracy: 86%
# [Step 2100] Past 100 steps: Average Loss 0.452 | Accuracy: 84%
# [Step 2200] Past 100 steps: Average Loss 0.715 | Accuracy: 74%
# [Step 2300] Past 100 steps: Average Loss 0.465 | Accuracy: 87%
# [Step 2400] Past 100 steps: Average Loss 0.624 | Accuracy: 78%
# [Step 2500] Past 100 steps: Average Loss 0.347 | Accuracy: 90%
# [Step 2600] Past 100 steps: Average Loss 0.630 | Accuracy: 81%
# [Step 2700] Past 100 steps: Average Loss 0.409 | Accuracy: 86%
# [Step 2800] Past 100 steps: Average Loss 0.368 | Accuracy: 90%
# [Step 2900] Past 100 steps: Average Loss 0.376 | Accuracy: 92%
# [Step 3000] Past 100 steps: Average Loss 0.399 | Accuracy: 84%
# [Step 3100] Past 100 steps: Average Loss 0.483 | Accuracy: 86%
# [Step 3200] Past 100 steps: Average Loss 0.437 | Accuracy: 83%
# [Step 3300] Past 100 steps: Average Loss 0.435 | Accuracy: 85%
# [Step 3400] Past 100 steps: Average Loss 0.459 | Accuracy: 85%
# [Step 3500] Past 100 steps: Average Loss 0.338 | Accuracy: 90%
# [Step 3600] Past 100 steps: Average Loss 0.247 | Accuracy: 95%
# [Step 3700] Past 100 steps: Average Loss 0.365 | Accuracy: 90%
# [Step 3800] Past 100 steps: Average Loss 0.430 | Accuracy: 88%
# [Step 3900] Past 100 steps: Average Loss 0.502 | Accuracy: 83%
# [Step 4000] Past 100 steps: Average Loss 0.509 | Accuracy: 84%
# [Step 4100] Past 100 steps: Average Loss 0.518 | Accuracy: 85%
# [Step 4200] Past 100 steps: Average Loss 0.269 | Accuracy: 91%
# [Step 4300] Past 100 steps: Average Loss 0.350 | Accuracy: 88%
# [Step 4400] Past 100 steps: Average Loss 0.336 | Accuracy: 87%
# [Step 4500] Past 100 steps: Average Loss 0.440 | Accuracy: 89%
# [Step 4600] Past 100 steps: Average Loss 0.380 | Accuracy: 91%
# [Step 4700] Past 100 steps: Average Loss 0.304 | Accuracy: 91%
# [Step 4800] Past 100 steps: Average Loss 0.471 | Accuracy: 88%
# [Step 4900] Past 100 steps: Average Loss 0.327 | Accuracy: 92%
# [Step 5000] Past 100 steps: Average Loss 0.301 | Accuracy: 90%
# [Step 5100] Past 100 steps: Average Loss 0.333 | Accuracy: 91%
# [Step 5200] Past 100 steps: Average Loss 0.470 | Accuracy: 85%
# [Step 5300] Past 100 steps: Average Loss 0.395 | Accuracy: 88%
# [Step 5400] Past 100 steps: Average Loss 0.484 | Accuracy: 87%
# [Step 5500] Past 100 steps: Average Loss 0.318 | Accuracy: 93%
# [Step 5600] Past 100 steps: Average Loss 0.603 | Accuracy: 82%
# [Step 5700] Past 100 steps: Average Loss 0.420 | Accuracy: 87%
# [Step 5800] Past 100 steps: Average Loss 0.324 | Accuracy: 91%
# [Step 5900] Past 100 steps: Average Loss 0.380 | Accuracy: 89%
# [Step 6000] Past 100 steps: Average Loss 0.374 | Accuracy: 89%
# [Step 6100] Past 100 steps: Average Loss 0.412 | Accuracy: 89%
# [Step 6200] Past 100 steps: Average Loss 0.507 | Accuracy: 84%
# [Step 6300] Past 100 steps: Average Loss 0.250 | Accuracy: 93%
# [Step 6400] Past 100 steps: Average Loss 0.375 | Accuracy: 88%
# [Step 6500] Past 100 steps: Average Loss 0.377 | Accuracy: 90%
# [Step 6600] Past 100 steps: Average Loss 0.416 | Accuracy: 86%
# [Step 6700] Past 100 steps: Average Loss 0.344 | Accuracy: 90%
# [Step 6800] Past 100 steps: Average Loss 0.366 | Accuracy: 90%
# [Step 6900] Past 100 steps: Average Loss 0.499 | Accuracy: 86%
# [Step 7000] Past 100 steps: Average Loss 0.409 | Accuracy: 88%
# [Step 7100] Past 100 steps: Average Loss 0.395 | Accuracy: 92%
# [Step 7200] Past 100 steps: Average Loss 0.272 | Accuracy: 89%
# [Step 7300] Past 100 steps: Average Loss 0.304 | Accuracy: 91%
# [Step 7400] Past 100 steps: Average Loss 0.333 | Accuracy: 89%
# [Step 7500] Past 100 steps: Average Loss 0.458 | Accuracy: 91%
# [Step 7600] Past 100 steps: Average Loss 0.362 | Accuracy: 90%
# [Step 7700] Past 100 steps: Average Loss 0.247 | Accuracy: 95%
# [Step 7800] Past 100 steps: Average Loss 0.168 | Accuracy: 95%
# [Step 7900] Past 100 steps: Average Loss 0.176 | Accuracy: 95%
# [Step 8000] Past 100 steps: Average Loss 0.465 | Accuracy: 87%
# [Step 8100] Past 100 steps: Average Loss 0.271 | Accuracy: 91%
# [Step 8200] Past 100 steps: Average Loss 0.213 | Accuracy: 92%
# [Step 8300] Past 100 steps: Average Loss 0.464 | Accuracy: 89%
# [Step 8400] Past 100 steps: Average Loss 0.430 | Accuracy: 89%
# [Step 8500] Past 100 steps: Average Loss 0.433 | Accuracy: 89%
# [Step 8600] Past 100 steps: Average Loss 0.291 | Accuracy: 91%
# [Step 8700] Past 100 steps: Average Loss 0.340 | Accuracy: 89%
# [Step 8800] Past 100 steps: Average Loss 0.231 | Accuracy: 95%
# [Step 8900] Past 100 steps: Average Loss 0.281 | Accuracy: 92%
# [Step 9000] Past 100 steps: Average Loss 0.358 | Accuracy: 89%
# [Step 9100] Past 100 steps: Average Loss 0.204 | Accuracy: 93%
# [Step 9200] Past 100 steps: Average Loss 0.147 | Accuracy: 95%
# [Step 9300] Past 100 steps: Average Loss 0.408 | Accuracy: 85%
# [Step 9400] Past 100 steps: Average Loss 0.284 | Accuracy: 93%
# [Step 9500] Past 100 steps: Average Loss 0.322 | Accuracy: 89%
# [Step 9600] Past 100 steps: Average Loss 0.455 | Accuracy: 84%
# [Step 9700] Past 100 steps: Average Loss 0.171 | Accuracy: 94%
# [Step 9800] Past 100 steps: Average Loss 0.461 | Accuracy: 85%
# [Step 9900] Past 100 steps: Average Loss 0.378 | Accuracy: 93%
# [Step 10000] Past 100 steps: Average Loss 0.315 | Accuracy: 90%
# --- Epoch 2 ---
# [Step 100] Past 100 steps: Average Loss 0.277 | Accuracy: 92%
# [Step 200] Past 100 steps: Average Loss 0.335 | Accuracy: 89%
# [Step 300] Past 100 steps: Average Loss 0.353 | Accuracy: 87%
# [Step 400] Past 100 steps: Average Loss 0.266 | Accuracy: 92%
# [Step 500] Past 100 steps: Average Loss 0.383 | Accuracy: 90%
# [Step 600] Past 100 steps: Average Loss 0.226 | Accuracy: 92%
# [Step 700] Past 100 steps: Average Loss 0.279 | Accuracy: 93%
# [Step 800] Past 100 steps: Average Loss 0.219 | Accuracy: 94%
# [Step 900] Past 100 steps: Average Loss 0.348 | Accuracy: 92%
# [Step 1000] Past 100 steps: Average Loss 0.149 | Accuracy: 97%
# [Step 1100] Past 100 steps: Average Loss 0.190 | Accuracy: 91%
# [Step 1200] Past 100 steps: Average Loss 0.241 | Accuracy: 92%
# [Step 1300] Past 100 steps: Average Loss 0.293 | Accuracy: 92%
# [Step 1400] Past 100 steps: Average Loss 0.407 | Accuracy: 87%
# [Step 1500] Past 100 steps: Average Loss 0.277 | Accuracy: 91%
# [Step 1600] Past 100 steps: Average Loss 0.276 | Accuracy: 92%
# [Step 1700] Past 100 steps: Average Loss 0.265 | Accuracy: 91%
# [Step 1800] Past 100 steps: Average Loss 0.382 | Accuracy: 90%
# [Step 1900] Past 100 steps: Average Loss 0.140 | Accuracy: 97%
# [Step 2000] Past 100 steps: Average Loss 0.186 | Accuracy: 93%
# [Step 2100] Past 100 steps: Average Loss 0.487 | Accuracy: 86%
# [Step 2200] Past 100 steps: Average Loss 0.455 | Accuracy: 87%
# [Step 2300] Past 100 steps: Average Loss 0.230 | Accuracy: 92%
# [Step 2400] Past 100 steps: Average Loss 0.197 | Accuracy: 95%
# [Step 2500] Past 100 steps: Average Loss 0.335 | Accuracy: 91%
# [Step 2600] Past 100 steps: Average Loss 0.263 | Accuracy: 90%
# [Step 2700] Past 100 steps: Average Loss 0.334 | Accuracy: 92%
# [Step 2800] Past 100 steps: Average Loss 0.206 | Accuracy: 92%
# [Step 2900] Past 100 steps: Average Loss 0.178 | Accuracy: 95%
# [Step 3000] Past 100 steps: Average Loss 0.334 | Accuracy: 88%
# [Step 3100] Past 100 steps: Average Loss 0.391 | Accuracy: 87%
# [Step 3200] Past 100 steps: Average Loss 0.248 | Accuracy: 93%
# [Step 3300] Past 100 steps: Average Loss 0.170 | Accuracy: 93%
# [Step 3400] Past 100 steps: Average Loss 0.224 | Accuracy: 91%
# [Step 3500] Past 100 steps: Average Loss 0.310 | Accuracy: 91%
# [Step 3600] Past 100 steps: Average Loss 0.301 | Accuracy: 92%
# [Step 3700] Past 100 steps: Average Loss 0.295 | Accuracy: 94%
# [Step 3800] Past 100 steps: Average Loss 0.238 | Accuracy: 95%
# [Step 3900] Past 100 steps: Average Loss 0.165 | Accuracy: 97%
# [Step 4000] Past 100 steps: Average Loss 0.468 | Accuracy: 90%
# [Step 4100] Past 100 steps: Average Loss 0.202 | Accuracy: 92%
# [Step 4200] Past 100 steps: Average Loss 0.237 | Accuracy: 93%
# [Step 4300] Past 100 steps: Average Loss 0.163 | Accuracy: 97%
# [Step 4400] Past 100 steps: Average Loss 0.222 | Accuracy: 92%
# [Step 4500] Past 100 steps: Average Loss 0.279 | Accuracy: 92%
# [Step 4600] Past 100 steps: Average Loss 0.162 | Accuracy: 94%
# [Step 4700] Past 100 steps: Average Loss 0.323 | Accuracy: 90%
# [Step 4800] Past 100 steps: Average Loss 0.288 | Accuracy: 92%
# [Step 4900] Past 100 steps: Average Loss 0.244 | Accuracy: 94%
# [Step 5000] Past 100 steps: Average Loss 0.171 | Accuracy: 97%
# [Step 5100] Past 100 steps: Average Loss 0.229 | Accuracy: 94%
# [Step 5200] Past 100 steps: Average Loss 0.194 | Accuracy: 94%
# [Step 5300] Past 100 steps: Average Loss 0.252 | Accuracy: 91%
# [Step 5400] Past 100 steps: Average Loss 0.345 | Accuracy: 92%
# [Step 5500] Past 100 steps: Average Loss 0.319 | Accuracy: 91%
# [Step 5600] Past 100 steps: Average Loss 0.337 | Accuracy: 90%
# [Step 5700] Past 100 steps: Average Loss 0.379 | Accuracy: 88%
# [Step 5800] Past 100 steps: Average Loss 0.278 | Accuracy: 92%
# [Step 5900] Past 100 steps: Average Loss 0.174 | Accuracy: 93%
# [Step 6000] Past 100 steps: Average Loss 0.251 | Accuracy: 90%
# [Step 6100] Past 100 steps: Average Loss 0.250 | Accuracy: 93%
# [Step 6200] Past 100 steps: Average Loss 0.247 | Accuracy: 90%
# [Step 6300] Past 100 steps: Average Loss 0.349 | Accuracy: 91%
# [Step 6400] Past 100 steps: Average Loss 0.494 | Accuracy: 89%
# [Step 6500] Past 100 steps: Average Loss 0.385 | Accuracy: 91%
# [Step 6600] Past 100 steps: Average Loss 0.443 | Accuracy: 87%
# [Step 6700] Past 100 steps: Average Loss 0.272 | Accuracy: 93%
# [Step 6800] Past 100 steps: Average Loss 0.170 | Accuracy: 96%
# [Step 6900] Past 100 steps: Average Loss 0.274 | Accuracy: 93%
# [Step 7000] Past 100 steps: Average Loss 0.239 | Accuracy: 96%
# [Step 7100] Past 100 steps: Average Loss 0.264 | Accuracy: 92%
# [Step 7200] Past 100 steps: Average Loss 0.160 | Accuracy: 96%
# [Step 7300] Past 100 steps: Average Loss 0.155 | Accuracy: 96%
# [Step 7400] Past 100 steps: Average Loss 0.231 | Accuracy: 95%
# [Step 7500] Past 100 steps: Average Loss 0.291 | Accuracy: 88%
# [Step 7600] Past 100 steps: Average Loss 0.186 | Accuracy: 93%
# [Step 7700] Past 100 steps: Average Loss 0.333 | Accuracy: 89%
# [Step 7800] Past 100 steps: Average Loss 0.311 | Accuracy: 91%
# [Step 7900] Past 100 steps: Average Loss 0.267 | Accuracy: 94%
# [Step 8000] Past 100 steps: Average Loss 0.204 | Accuracy: 94%
# [Step 8100] Past 100 steps: Average Loss 0.267 | Accuracy: 93%
# [Step 8200] Past 100 steps: Average Loss 0.208 | Accuracy: 94%
# [Step 8300] Past 100 steps: Average Loss 0.219 | Accuracy: 97%
# [Step 8400] Past 100 steps: Average Loss 0.271 | Accuracy: 93%
# [Step 8500] Past 100 steps: Average Loss 0.183 | Accuracy: 95%
# [Step 8600] Past 100 steps: Average Loss 0.260 | Accuracy: 93%
# [Step 8700] Past 100 steps: Average Loss 0.190 | Accuracy: 94%
# [Step 8800] Past 100 steps: Average Loss 0.433 | Accuracy: 87%
# [Step 8900] Past 100 steps: Average Loss 0.292 | Accuracy: 94%
# [Step 9000] Past 100 steps: Average Loss 0.130 | Accuracy: 97%
# [Step 9100] Past 100 steps: Average Loss 0.271 | Accuracy: 91%
# [Step 9200] Past 100 steps: Average Loss 0.317 | Accuracy: 91%
# [Step 9300] Past 100 steps: Average Loss 0.340 | Accuracy: 91%
# [Step 9400] Past 100 steps: Average Loss 0.267 | Accuracy: 91%
# [Step 9500] Past 100 steps: Average Loss 0.448 | Accuracy: 90%
# [Step 9600] Past 100 steps: Average Loss 0.188 | Accuracy: 96%
# [Step 9700] Past 100 steps: Average Loss 0.168 | Accuracy: 94%
# [Step 9800] Past 100 steps: Average Loss 0.198 | Accuracy: 94%
# [Step 9900] Past 100 steps: Average Loss 0.131 | Accuracy: 97%
# [Step 10000] Past 100 steps: Average Loss 0.225 | Accuracy: 92%
# --- Epoch 3 ---
# [Step 100] Past 100 steps: Average Loss 0.209 | Accuracy: 92%
# [Step 200] Past 100 steps: Average Loss 0.330 | Accuracy: 91%
# [Step 300] Past 100 steps: Average Loss 0.248 | Accuracy: 91%
# [Step 400] Past 100 steps: Average Loss 0.142 | Accuracy: 94%
# [Step 500] Past 100 steps: Average Loss 0.197 | Accuracy: 96%
# [Step 600] Past 100 steps: Average Loss 0.166 | Accuracy: 96%
# [Step 700] Past 100 steps: Average Loss 0.206 | Accuracy: 96%
# [Step 800] Past 100 steps: Average Loss 0.311 | Accuracy: 91%
# [Step 900] Past 100 steps: Average Loss 0.204 | Accuracy: 92%
# [Step 1000] Past 100 steps: Average Loss 0.316 | Accuracy: 90%
# [Step 1100] Past 100 steps: Average Loss 0.174 | Accuracy: 94%
# [Step 1200] Past 100 steps: Average Loss 0.081 | Accuracy: 98%
# [Step 1300] Past 100 steps: Average Loss 0.301 | Accuracy: 94%
# [Step 1400] Past 100 steps: Average Loss 0.164 | Accuracy: 93%
# [Step 1500] Past 100 steps: Average Loss 0.187 | Accuracy: 96%
# [Step 1600] Past 100 steps: Average Loss 0.164 | Accuracy: 96%
# [Step 1700] Past 100 steps: Average Loss 0.257 | Accuracy: 92%
# [Step 1800] Past 100 steps: Average Loss 0.337 | Accuracy: 93%
# [Step 1900] Past 100 steps: Average Loss 0.241 | Accuracy: 92%
# [Step 2000] Past 100 steps: Average Loss 0.266 | Accuracy: 94%
# [Step 2100] Past 100 steps: Average Loss 0.179 | Accuracy: 95%
# [Step 2200] Past 100 steps: Average Loss 0.170 | Accuracy: 93%
# [Step 2300] Past 100 steps: Average Loss 0.160 | Accuracy: 97%
# [Step 2400] Past 100 steps: Average Loss 0.183 | Accuracy: 94%
# [Step 2500] Past 100 steps: Average Loss 0.275 | Accuracy: 90%
# [Step 2600] Past 100 steps: Average Loss 0.305 | Accuracy: 95%
# [Step 2700] Past 100 steps: Average Loss 0.120 | Accuracy: 98%
# [Step 2800] Past 100 steps: Average Loss 0.147 | Accuracy: 95%
# [Step 2900] Past 100 steps: Average Loss 0.149 | Accuracy: 95%
# [Step 3000] Past 100 steps: Average Loss 0.357 | Accuracy: 90%
# [Step 3100] Past 100 steps: Average Loss 0.067 | Accuracy: 98%
# [Step 3200] Past 100 steps: Average Loss 0.248 | Accuracy: 91%
# [Step 3300] Past 100 steps: Average Loss 0.262 | Accuracy: 89%
# [Step 3400] Past 100 steps: Average Loss 0.123 | Accuracy: 97%
# [Step 3500] Past 100 steps: Average Loss 0.249 | Accuracy: 93%
# [Step 3600] Past 100 steps: Average Loss 0.144 | Accuracy: 95%
# [Step 3700] Past 100 steps: Average Loss 0.085 | Accuracy: 99%
# [Step 3800] Past 100 steps: Average Loss 0.253 | Accuracy: 91%
# [Step 3900] Past 100 steps: Average Loss 0.157 | Accuracy: 94%
# [Step 4000] Past 100 steps: Average Loss 0.295 | Accuracy: 90%
# [Step 4100] Past 100 steps: Average Loss 0.190 | Accuracy: 94%
# [Step 4200] Past 100 steps: Average Loss 0.290 | Accuracy: 87%
# [Step 4300] Past 100 steps: Average Loss 0.242 | Accuracy: 94%
# [Step 4400] Past 100 steps: Average Loss 0.294 | Accuracy: 94%
# [Step 4500] Past 100 steps: Average Loss 0.183 | Accuracy: 96%
# [Step 4600] Past 100 steps: Average Loss 0.138 | Accuracy: 96%
# [Step 4700] Past 100 steps: Average Loss 0.281 | Accuracy: 96%
# [Step 4800] Past 100 steps: Average Loss 0.179 | Accuracy: 95%
# [Step 4900] Past 100 steps: Average Loss 0.276 | Accuracy: 92%
# [Step 5000] Past 100 steps: Average Loss 0.231 | Accuracy: 93%
# [Step 5100] Past 100 steps: Average Loss 0.218 | Accuracy: 94%
# [Step 5200] Past 100 steps: Average Loss 0.230 | Accuracy: 95%
# [Step 5300] Past 100 steps: Average Loss 0.176 | Accuracy: 95%
# [Step 5400] Past 100 steps: Average Loss 0.173 | Accuracy: 95%
# [Step 5500] Past 100 steps: Average Loss 0.236 | Accuracy: 92%
# [Step 5600] Past 100 steps: Average Loss 0.344 | Accuracy: 90%
# [Step 5700] Past 100 steps: Average Loss 0.165 | Accuracy: 97%
# [Step 5800] Past 100 steps: Average Loss 0.149 | Accuracy: 97%
# [Step 5900] Past 100 steps: Average Loss 0.127 | Accuracy: 97%
# [Step 6000] Past 100 steps: Average Loss 0.329 | Accuracy: 90%
# [Step 6100] Past 100 steps: Average Loss 0.136 | Accuracy: 96%
# [Step 6200] Past 100 steps: Average Loss 0.154 | Accuracy: 95%
# [Step 6300] Past 100 steps: Average Loss 0.083 | Accuracy: 97%
# [Step 6400] Past 100 steps: Average Loss 0.093 | Accuracy: 97%
# [Step 6500] Past 100 steps: Average Loss 0.328 | Accuracy: 91%
# [Step 6600] Past 100 steps: Average Loss 0.309 | Accuracy: 91%
# [Step 6700] Past 100 steps: Average Loss 0.157 | Accuracy: 95%
# [Step 6800] Past 100 steps: Average Loss 0.143 | Accuracy: 92%
# [Step 6900] Past 100 steps: Average Loss 0.183 | Accuracy: 95%
# [Step 7000] Past 100 steps: Average Loss 0.113 | Accuracy: 95%
# [Step 7100] Past 100 steps: Average Loss 0.157 | Accuracy: 96%
# [Step 7200] Past 100 steps: Average Loss 0.240 | Accuracy: 91%
# [Step 7300] Past 100 steps: Average Loss 0.073 | Accuracy: 99%
# [Step 7400] Past 100 steps: Average Loss 0.081 | Accuracy: 100%
# [Step 7500] Past 100 steps: Average Loss 0.150 | Accuracy: 95%
# [Step 7600] Past 100 steps: Average Loss 0.202 | Accuracy: 94%
# [Step 7700] Past 100 steps: Average Loss 0.102 | Accuracy: 96%
# [Step 7800] Past 100 steps: Average Loss 0.203 | Accuracy: 96%
# [Step 7900] Past 100 steps: Average Loss 0.127 | Accuracy: 95%
# [Step 8000] Past 100 steps: Average Loss 0.104 | Accuracy: 96%
# [Step 8100] Past 100 steps: Average Loss 0.161 | Accuracy: 94%
# [Step 8200] Past 100 steps: Average Loss 0.112 | Accuracy: 97%
# [Step 8300] Past 100 steps: Average Loss 0.165 | Accuracy: 95%
# [Step 8400] Past 100 steps: Average Loss 0.156 | Accuracy: 95%
# [Step 8500] Past 100 steps: Average Loss 0.111 | Accuracy: 97%
# [Step 8600] Past 100 steps: Average Loss 0.219 | Accuracy: 92%
# [Step 8700] Past 100 steps: Average Loss 0.117 | Accuracy: 96%
# [Step 8800] Past 100 steps: Average Loss 0.160 | Accuracy: 94%
# [Step 8900] Past 100 steps: Average Loss 0.252 | Accuracy: 91%
# [Step 9000] Past 100 steps: Average Loss 0.322 | Accuracy: 93%
# [Step 9100] Past 100 steps: Average Loss 0.273 | Accuracy: 93%
# [Step 9200] Past 100 steps: Average Loss 0.161 | Accuracy: 96%
# [Step 9300] Past 100 steps: Average Loss 0.261 | Accuracy: 91%
# [Step 9400] Past 100 steps: Average Loss 0.304 | Accuracy: 92%
# [Step 9500] Past 100 steps: Average Loss 0.151 | Accuracy: 96%
# [Step 9600] Past 100 steps: Average Loss 0.286 | Accuracy: 93%
# [Step 9700] Past 100 steps: Average Loss 0.207 | Accuracy: 94%
# [Step 9800] Past 100 steps: Average Loss 0.142 | Accuracy: 95%
# [Step 9900] Past 100 steps: Average Loss 0.190 | Accuracy: 95%
# [Step 10000] Past 100 steps: Average Loss 0.229 | Accuracy: 96%
# --- Epoch 4 ---
# [Step 100] Past 100 steps: Average Loss 0.096 | Accuracy: 95%
# [Step 200] Past 100 steps: Average Loss 0.085 | Accuracy: 97%
# [Step 300] Past 100 steps: Average Loss 0.175 | Accuracy: 93%
# [Step 400] Past 100 steps: Average Loss 0.125 | Accuracy: 97%
# [Step 500] Past 100 steps: Average Loss 0.271 | Accuracy: 93%
# [Step 600] Past 100 steps: Average Loss 0.209 | Accuracy: 94%
# [Step 700] Past 100 steps: Average Loss 0.207 | Accuracy: 96%
# [Step 800] Past 100 steps: Average Loss 0.158 | Accuracy: 96%
# [Step 900] Past 100 steps: Average Loss 0.213 | Accuracy: 96%
# [Step 1000] Past 100 steps: Average Loss 0.223 | Accuracy: 93%
# [Step 1100] Past 100 steps: Average Loss 0.093 | Accuracy: 97%
# [Step 1200] Past 100 steps: Average Loss 0.129 | Accuracy: 96%
# [Step 1300] Past 100 steps: Average Loss 0.152 | Accuracy: 95%
# [Step 1400] Past 100 steps: Average Loss 0.217 | Accuracy: 93%
# [Step 1500] Past 100 steps: Average Loss 0.156 | Accuracy: 96%
# [Step 1600] Past 100 steps: Average Loss 0.261 | Accuracy: 94%
# [Step 1700] Past 100 steps: Average Loss 0.133 | Accuracy: 98%
# [Step 1800] Past 100 steps: Average Loss 0.078 | Accuracy: 99%
# [Step 1900] Past 100 steps: Average Loss 0.120 | Accuracy: 96%
# [Step 2000] Past 100 steps: Average Loss 0.054 | Accuracy: 100%
# [Step 2100] Past 100 steps: Average Loss 0.159 | Accuracy: 96%
# [Step 2200] Past 100 steps: Average Loss 0.205 | Accuracy: 94%
# [Step 2300] Past 100 steps: Average Loss 0.242 | Accuracy: 95%
# [Step 2400] Past 100 steps: Average Loss 0.199 | Accuracy: 96%
# [Step 2500] Past 100 steps: Average Loss 0.142 | Accuracy: 94%
# [Step 2600] Past 100 steps: Average Loss 0.192 | Accuracy: 98%
# [Step 2700] Past 100 steps: Average Loss 0.150 | Accuracy: 94%
# [Step 2800] Past 100 steps: Average Loss 0.082 | Accuracy: 98%
# [Step 2900] Past 100 steps: Average Loss 0.248 | Accuracy: 91%
# [Step 3000] Past 100 steps: Average Loss 0.259 | Accuracy: 93%
# [Step 3100] Past 100 steps: Average Loss 0.180 | Accuracy: 95%
# [Step 3200] Past 100 steps: Average Loss 0.192 | Accuracy: 96%
# [Step 3300] Past 100 steps: Average Loss 0.095 | Accuracy: 96%
# [Step 3400] Past 100 steps: Average Loss 0.173 | Accuracy: 94%
# [Step 3500] Past 100 steps: Average Loss 0.075 | Accuracy: 99%
# [Step 3600] Past 100 steps: Average Loss 0.138 | Accuracy: 95%
# [Step 3700] Past 100 steps: Average Loss 0.081 | Accuracy: 98%
# [Step 3800] Past 100 steps: Average Loss 0.171 | Accuracy: 92%
# [Step 3900] Past 100 steps: Average Loss 0.103 | Accuracy: 97%
# [Step 4000] Past 100 steps: Average Loss 0.190 | Accuracy: 94%
# [Step 4100] Past 100 steps: Average Loss 0.122 | Accuracy: 98%
# [Step 4200] Past 100 steps: Average Loss 0.124 | Accuracy: 98%
# [Step 4300] Past 100 steps: Average Loss 0.147 | Accuracy: 94%
# [Step 4400] Past 100 steps: Average Loss 0.152 | Accuracy: 96%
# [Step 4500] Past 100 steps: Average Loss 0.123 | Accuracy: 96%
# [Step 4600] Past 100 steps: Average Loss 0.067 | Accuracy: 98%
# [Step 4700] Past 100 steps: Average Loss 0.235 | Accuracy: 94%
# [Step 4800] Past 100 steps: Average Loss 0.164 | Accuracy: 95%
# [Step 4900] Past 100 steps: Average Loss 0.116 | Accuracy: 98%
# [Step 5000] Past 100 steps: Average Loss 0.170 | Accuracy: 95%
# [Step 5100] Past 100 steps: Average Loss 0.118 | Accuracy: 97%
# [Step 5200] Past 100 steps: Average Loss 0.138 | Accuracy: 97%
# [Step 5300] Past 100 steps: Average Loss 0.104 | Accuracy: 98%
# [Step 5400] Past 100 steps: Average Loss 0.137 | Accuracy: 96%
# [Step 5500] Past 100 steps: Average Loss 0.196 | Accuracy: 93%
# [Step 5600] Past 100 steps: Average Loss 0.185 | Accuracy: 94%
# [Step 5700] Past 100 steps: Average Loss 0.132 | Accuracy: 98%
# [Step 5800] Past 100 steps: Average Loss 0.211 | Accuracy: 93%
# [Step 5900] Past 100 steps: Average Loss 0.263 | Accuracy: 95%
# [Step 6000] Past 100 steps: Average Loss 0.091 | Accuracy: 97%
# [Step 6100] Past 100 steps: Average Loss 0.146 | Accuracy: 97%
# [Step 6200] Past 100 steps: Average Loss 0.232 | Accuracy: 95%
# [Step 6300] Past 100 steps: Average Loss 0.121 | Accuracy: 97%
# [Step 6400] Past 100 steps: Average Loss 0.164 | Accuracy: 94%
# [Step 6500] Past 100 steps: Average Loss 0.065 | Accuracy: 98%
# [Step 6600] Past 100 steps: Average Loss 0.293 | Accuracy: 94%
# [Step 6700] Past 100 steps: Average Loss 0.151 | Accuracy: 95%
# [Step 6800] Past 100 steps: Average Loss 0.123 | Accuracy: 97%
# [Step 6900] Past 100 steps: Average Loss 0.126 | Accuracy: 96%
# [Step 7000] Past 100 steps: Average Loss 0.134 | Accuracy: 97%
# [Step 7100] Past 100 steps: Average Loss 0.095 | Accuracy: 98%
# [Step 7200] Past 100 steps: Average Loss 0.226 | Accuracy: 91%
# [Step 7300] Past 100 steps: Average Loss 0.364 | Accuracy: 85%
# [Step 7400] Past 100 steps: Average Loss 0.249 | Accuracy: 92%
# [Step 7500] Past 100 steps: Average Loss 0.181 | Accuracy: 95%
# [Step 7600] Past 100 steps: Average Loss 0.049 | Accuracy: 98%
# [Step 7700] Past 100 steps: Average Loss 0.118 | Accuracy: 95%
# [Step 7800] Past 100 steps: Average Loss 0.098 | Accuracy: 98%
# [Step 7900] Past 100 steps: Average Loss 0.131 | Accuracy: 94%
# [Step 8000] Past 100 steps: Average Loss 0.227 | Accuracy: 97%
# [Step 8100] Past 100 steps: Average Loss 0.125 | Accuracy: 95%
# [Step 8200] Past 100 steps: Average Loss 0.154 | Accuracy: 96%
# [Step 8300] Past 100 steps: Average Loss 0.163 | Accuracy: 94%
# [Step 8400] Past 100 steps: Average Loss 0.136 | Accuracy: 97%
# [Step 8500] Past 100 steps: Average Loss 0.121 | Accuracy: 96%
# [Step 8600] Past 100 steps: Average Loss 0.153 | Accuracy: 96%
# [Step 8700] Past 100 steps: Average Loss 0.110 | Accuracy: 97%
# [Step 8800] Past 100 steps: Average Loss 0.214 | Accuracy: 95%
# [Step 8900] Past 100 steps: Average Loss 0.114 | Accuracy: 97%
# [Step 9000] Past 100 steps: Average Loss 0.106 | Accuracy: 97%
# [Step 9100] Past 100 steps: Average Loss 0.180 | Accuracy: 95%
# [Step 9200] Past 100 steps: Average Loss 0.109 | Accuracy: 96%
# [Step 9300] Past 100 steps: Average Loss 0.072 | Accuracy: 97%
# [Step 9400] Past 100 steps: Average Loss 0.242 | Accuracy: 97%
# [Step 9500] Past 100 steps: Average Loss 0.195 | Accuracy: 95%
# [Step 9600] Past 100 steps: Average Loss 0.241 | Accuracy: 93%
# [Step 9700] Past 100 steps: Average Loss 0.173 | Accuracy: 94%
# [Step 9800] Past 100 steps: Average Loss 0.246 | Accuracy: 93%
# [Step 9900] Past 100 steps: Average Loss 0.146 | Accuracy: 96%
# [Step 10000] Past 100 steps: Average Loss 0.321 | Accuracy: 91%
# Accuracy over epochs:  [0.856, 0.9225, 0.9417, 0.955]
#
# --- Testing the CNN ---
# Test Loss: 0.1987688962867394
# Test Accuracy: 0.9424

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.inferno):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "white")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
cm = confusion_matrix(test_labels,pred)
cm_plot = plot_confusion_matrix(cm,classes=[])

# %%
print('Performance Report (Accuracy score on test set) :', format(metrics.accuracy_score(test_labels, pred), '.2f'),'\n\n')
target=[str(i) for i in range(10)]
print('Classification Report'.center(65,'-'),'\n', metrics.classification_report(test_labels, pred,target_names=target))
# Out:
# Performance Report (Accuracy score on test set) : 0.93
#
#
# ----------------------Classification Report----------------------
#                precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88       980
#            1       0.98      0.98      0.98      1135
#            2       0.87      0.96      0.91      1032
#            3       0.97      0.90      0.93      1010
#            4       0.97      0.93      0.95       982
#            5       0.99      0.87      0.92       892
#            6       0.96      0.94      0.95       958
#            7       0.96      0.90      0.93      1028
#            8       0.92      0.93      0.93       974
#            9       0.96      0.92      0.94      1009
#
#     accuracy                           0.93     10000
#    macro avg       0.94      0.93      0.93     10000
# weighted avg       0.94      0.93      0.93     10000
